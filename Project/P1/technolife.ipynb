# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("technolife_phones.csv")
dataset[dataset["OS"].isnull()]
# Out:
#                                                  Name  \
# 147                              GLX General Luxe 105
# 166                            Alcatel 1069 Dual SIM
# 167                      GLX Classic F8 Plus Dual Sim
# 190               Nokia 130 (2017) Dual SIM 8/4MB RAM
# 191                     GLX General Luxe 106 Dual SIM
# 207                    Nokia 216 Dual SIM 16/16MB RAM
# 209                               Nokia 216 Dual SIM
# 215                  Nokia 210 (2019) - Iran Assembly
# 225                         Nokia 130 (2017) Dual SIM
# 228                  GLX 2690 Gold Mini Plus Dual Sim
# 239                        Nokia 210 (2019) Dual SIM
# 247                       Nokia 5310 (2020) Dual SIM
# 248                       Nokia 5310 (2020) Dual SIM
# 297                                 Otel F05 Dual SIM
# 309                                 Otel F06 Dual SIM
# 341                                Otel F05c Dual SIM
# ...
